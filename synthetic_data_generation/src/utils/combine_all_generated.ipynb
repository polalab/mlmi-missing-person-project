# %%
import sys
import os
parent_dir = os.path.abspath(os.path.join(os.getcwd(), '../..'))

if parent_dir not in sys.path:
    sys.path.append(parent_dir)

from src.utils.initial_generation_statistics import missing_person_patterns

# %%
# COMBINE MP
import glob
import pandas as pd
import os
import numpy as np

def concatenate_full_data_csvs(output_filename='../../data/full/fake_mp_data_correct.csv'):
    file_paths = glob.glob('../../data/**/processed/add_circumstances/mp_full_data.csv', recursive=True)
    print(file_paths)
    if not file_paths:
        print("No 'dataframe_circumstances.csv' files found in any subdirectories.")
        return
    
    filtered_file_paths = [
        f for f in file_paths
        if 'processed' in os.path.normpath(f).replace(os.sep, '/')
    ]
    
    if not filtered_file_paths:
        print("No 'full_data.csv' files matching the 'add_cir' pattern were found.")
        return
    
    print(f"Found {len(filtered_file_paths)} matching files:")
    for f in filtered_file_paths:
        print(f"- {f}")
    
    all_dataframes = []
    for file_path in filtered_file_paths:
        try:
            df = pd.read_csv(file_path)
            all_dataframes.append(df)
        except Exception as e:
            print(f"Error reading {file_path}: {e}. Skipping this file.")
    
    if not all_dataframes:
        print("No DataFrames were successfully read to concatenate.")
        return
    
    # Concatenate all DataFrames into a single DataFrame
    combined_df = pd.concat(all_dataframes, ignore_index=True)
    
    # Convert float columns that are actually integers back to integers
    for col in combined_df.columns:
        if combined_df[col].dtype == 'float64':
            # Check if all non-null values are whole numbers
            non_null_values = combined_df[col].dropna()
            if len(non_null_values) > 0 and all(non_null_values == non_null_values.astype(int)):
                # Convert to nullable integer type to handle potential NaN values
                combined_df[col] = combined_df[col].astype('Int64')
    
    # Save the combined DataFrame to a new CSV file
    try:
        combined_df.to_csv(output_filename, index=False)
        print(f"\nAll matching 'full_data.csv' files have been concatenated into '{output_filename}'.")
        print(f"Combined DataFrame shape: {combined_df.shape}")
        
        # Print data types for verification
        print("\nColumn data types:")
        for col, dtype in combined_df.dtypes.items():
            print(f"  {col}: {dtype}")
            
    except Exception as e:
        print(f"Error saving the combined CSV to '{output_filename}': {e}")

    ids = set()
    for f in filtered_file_paths:
        ids.add(f.split('/')[3])
    return ids
id_mp=concatenate_full_data_csvs()
id_mp
# Out:
# ['../../data/4386/processed/add_circumstances/mp_full_data.csv', '../../data/1864/processed/add_circumstances/mp_full_data.csv', '../../data/5433/processed/add_circumstances/mp_full_data.csv', '../../data/8542/processed/add_circumstances/mp_full_data.csv', '../../data/4512/processed/add_circumstances/mp_full_data.csv', '../../data/4182/processed/add_circumstances/mp_full_data.csv', '../../data/6681/processed/add_circumstances/mp_full_data.csv', '../../data/157/processed/add_circumstances/mp_full_data.csv', '../../data/2470/processed/add_circumstances/mp_full_data.csv', '../../data/2817/processed/add_circumstances/mp_full_data.csv', '../../data/8723/processed/add_circumstances/mp_full_data.csv', '../../data/6827/processed/add_circumstances/mp_full_data.csv', '../../data/8940/processed/add_circumstances/mp_full_data.csv', '../../data/2674/processed/add_circumstances/mp_full_data.csv', '../../data/1839/processed/add_circumstances/mp_full_data.csv', '../../data/3938/processed/add_circumstances/mp_full_data.csv', '../../data/1466/processed/add_circumstances/mp_full_data.csv', '../../data/962/processed/add_circumstances/mp_full_data.csv', '../../data/9062/processed/add_circumstances/mp_full_data.csv', '../../data/6875/processed/add_circumstances/mp_full_data.csv', '../../data/5051/processed/add_circumstances/mp_full_data.csv', '../../data/6082/processed/add_circumstances/mp_full_data.csv', '../../data/2280/processed/add_circumstances/mp_full_data.csv', '../../data/9650/processed/add_circumstances/mp_full_data.csv', '../../data/51/processed/add_circumstances/mp_full_data.csv', '../../data/9039/processed/add_circumstances/mp_full_data.csv', '../../data/5264/processed/add_circumstances/mp_full_data.csv', '../../data/8575/processed/add_circumstances/mp_full_data.csv', '../../data/908/processed/add_circumstances/mp_full_data.csv', '../../data/8111/processed/add_circumstances/mp_full_data.csv', '../../data/5631/processed/add_circumstances/mp_full_data.csv', '../../data/7132/processed/add_circumstances/mp_full_data.csv', '../../data/4115/processed/add_circumstances/mp_full_data.csv', '../../data/2686/processed/add_circumstances/mp_full_data.csv', '../../data/8713/processed/add_circumstances/mp_full_data.csv', '../../data/9635/processed/add_circumstances/mp_full_data.csv', '../../data/2681/processed/add_circumstances/mp_full_data.csv', '../../data/8526/processed/add_circumstances/mp_full_data.csv', '../../data/7594/processed/add_circumstances/mp_full_data.csv', '../../data/5806/processed/add_circumstances/mp_full_data.csv', '../../data/9315/processed/add_circumstances/mp_full_data.csv', '../../data/1375/processed/add_circumstances/mp_full_data.csv', '../../data/1381/processed/add_circumstances/mp_full_data.csv', '../../data/7288/processed/add_circumstances/mp_full_data.csv', '../../data/5179/processed/add_circumstances/mp_full_data.csv', '../../data/2738/processed/add_circumstances/mp_full_data.csv', '../../data/5942/processed/add_circumstances/mp_full_data.csv', '../../data/1727/processed/add_circumstances/mp_full_data.csv', '../../data/3827/processed/add_circumstances/mp_full_data.csv', '../../data/422/processed/add_circumstances/mp_full_data.csv', '../../data/8256/processed/add_circumstances/mp_full_data.csv', '../../data/5772/processed/add_circumstances/mp_full_data.csv', '../../data/3811/processed/add_circumstances/mp_full_data.csv', '../../data/2937/processed/add_circumstances/mp_full_data.csv', '../../data/7479/processed/add_circumstances/mp_full_data.csv', '../../data/8431/processed/add_circumstances/mp_full_data.csv', '../../data/8455/processed/add_circumstances/mp_full_data.csv', '../../data/5523/processed/add_circumstances/mp_full_data.csv', '../../data/9545/processed/add_circumstances/mp_full_data.csv', '../../data/1989/processed/add_circumstances/mp_full_data.csv', '../../data/9126/processed/add_circumstances/mp_full_data.csv', '../../data/2338/processed/add_circumstances/mp_full_data.csv', '../../data/9516/processed/add_circum ...
# Found 300 matching files:
# - ../../data/4386/processed/add_circumstances/mp_full_data.csv
# - ../../data/1864/processed/add_circumstances/mp_full_data.csv
# - ../../data/5433/processed/add_circumstances/mp_full_data.csv
# - ../../data/8542/processed/add_circumstances/mp_full_data.csv
# - ../../data/4512/processed/add_circumstances/mp_full_data.csv
# - ../../data/4182/processed/add_circumstances/mp_full_data.csv
# - ../../data/6681/processed/add_circumstances/mp_full_data.csv
# - ../../data/157/processed/add_circumstances/mp_full_data.csv
# - ../../data/2470/processed/add_circumstances/mp_full_data.csv
# - ../../data/2817/processed/add_circumstances/mp_full_data.csv
# - ../../data/8723/processed/add_circumstances/mp_full_data.csv
# - ../../data/6827/processed/add_circumstances/mp_full_data.csv
# - ../../data/8940/processed/add_circumstances/mp_full_data.csv
# - ../../data/2674/processed/add_circumstances/mp_full_data.csv
# - ../../data/1839/processed/add_circumstances/mp_full_data.csv
# - ../../data/3938/processed/add_circumstances/mp_full_data.csv
# - ../../data/1466/processed/add_circumstances/mp_full_data.csv
# - ../../data/962/processed/add_circumstances/mp_full_data.csv
# - ../../data/9062/processed/add_circumstances/mp_full_data.csv
# - ../../data/6875/processed/add_circumstances/mp_full_data.csv
# - ../../data/5051/processed/add_circumstances/mp_full_data.csv
# - ../../data/6082/processed/add_circumstances/mp_full_data.csv
# - ../../data/2280/processed/add_circumstances/mp_full_data.csv
# - ../../data/9650/processed/add_circumstances/mp_full_data.csv
# - ../../data/51/processed/add_circumstances/mp_full_data.csv
# - ../../data/9039/processed/add_circumstances/mp_full_data.csv
# - ../../data/5264/processed/add_circumstances/mp_full_data.csv
# - ../../data/8575/processed/add_circumstances/mp_full_data.csv
# - ../../data/908/processed/add_circumstances/mp_full_data.csv
# - ../../data/8111/processed/add_circumstances/mp_full_data.csv
# - ../../data/5631/processed/add_circumstances/mp_full_data.csv
# - ../../data/7132/processed/add_circumstances/mp_full_data.csv
# - ../../data/4115/processed/add_circumstances/mp_full_data.csv
# - ../../data/2686/processed/add_circumstances/mp_full_data.csv
# - ../../data/8713/processed/add_circumstances/mp_full_data.csv
# - ../../data/9635/processed/add_circumstances/mp_full_data.csv
# - ../../data/2681/processed/add_circumstances/mp_full_data.csv
# - ../../data/8526/processed/add_circumstances/mp_full_data.csv
# - ../../data/7594/processed/add_circumstances/mp_full_data.csv
# - ../../data/5806/processed/add_circumstances/mp_full_data.csv
# - ../../data/9315/processed/add_circumstances/mp_full_data.csv
# - ../../data/1375/processed/add_circumstances/mp_full_data.csv
# - ../../data/1381/processed/add_circumstances/mp_full_data.csv
# - ../../data/7288/processed/add_circumstances/mp_full_data.csv
# - ../../data/5179/processed/add_circumstances/mp_full_data.csv
# - ../../data/2738/processed/add_circumstances/mp_full_data.csv
# - ../../data/5942/processed/add_circumstances/mp_full_data.csv
# - ../../data/1727/processed/add_circumstances/mp_full_data.csv
# - ../../data/3827/processed/add_circumstances/mp_full_data.csv
# - ../../data/422/processed/add_circumstances/mp_full_data.csv
# - ../../data/8256/processed/add_circumstances/mp_full_data.csv
# - ../../data/5772/processed/add_circumstances/mp_full_data.csv
# - ../../data/3811/processed/add_circumstances/mp_full_data.csv
# - ../../data/2937/processed/add_circumstances/mp_full_data.csv
# - ../../data/7479/processed/add_circumstances/mp_full_data.csv
# - ../../data/8431/processed/add_circumstances/mp_full_data.csv
# - ../../data/8455/processed/add_circumstances/mp_full_data.csv
# - ../../data/5523/processed/add_circumstances/mp_full_data.csv
# - ../../data/9545/processed/add_circumstances/mp_full_data.csv
# - ../../data/1989/processed/add_circumstances/mp_full_data.csv
# - ../../data/9126/processed/add_circumstances/mp_full_data.csv
# - ../../data/2338/processed/add_circumstances/mp_full_data.csv
# - ../../data/9516/processed/add_circumstances/mp_full_data.csv
# - ../../data/7686/processed/add_circumstances/mp_full_data.csv
# - ../../data/281/processed/add_circumstances/mp_full_data.csv
# - ../../data/8096/processed/add_circumstances/mp_full_data.csv
# - ../../data/9354/processed/add_circumstances/mp_full_data.csv
# - ../../data/6575/processed/add_circumstances/mp_full_data.csv
# - ../../data/3651/processed/add_circumstances/mp_full_data.csv
# - ../../data/4474/processed/add_circumstances/mp_full_data.csv
# - ../../data/9505/processed/add_circumstances/mp_full_data.csv
# - ../../data/9737/processed/add_circumstances/mp_full_data.csv
# - ../../data/6116/processed/add_circumstances/mp_full_data.csv
# - ../../data/266/processed/add_circumstances/mp_full_data.csv
# - ../../data/5904/processed/add_circumstances/mp_full_data.csv
# - ../../data/857/processed/add_circumstances/mp_full_data.csv
# - ../../data/7668/processed/add_circumstances/mp_full_data.csv
# - ../../data/5564/processed/add_circumstances/mp_full_data.csv
# - ../../data/8479/processed/add_circumstances/mp_full_data.csv
# - ../../data/3633/processed/add_circumstances/mp_full_data.csv
# - ../../data/6722/processed/add_circumstances/mp_full_data.csv
# - ../../data/490/processed/add_circumstances/mp_full_data.csv
# - ../../data/7851/processed/add_circumstances/mp_full_data.csv
# - ../../data/5508/processed/add_circumstances/mp_full_data.csv
# - ../../data/656/processed/add_circumstances/mp_full_data.csv
# - ../../data/3602/processed/add_circumstances/mp_full_data.csv
# - ../../data/2516/processed/add_circumstances/mp_full_data.csv
# - ../../data/2971/processed/add_circumstances/mp_full_data.csv
# - ../../data/6383/processed/add_circumstances/mp_full_data.csv
# - ../../data/2915/processed/add_circumstances/mp_full_data.csv
# - ../../data/5902/processed/add_circumstances/mp_full_data.csv
# - ../../data/6542/processed/add_circumstances/mp_full_data.csv
# - ../../data/2324/processed/add_circumstances/mp_full_data.csv
# - ../../data/851/processed/add_circumstances/mp_full_data.csv
# - ../../data/4649/processed/add_circumstances/mp_full_data.csv
# - ../../data/9156/processed/add_circumstances/mp_full_data.csv
# - ../../data/3465/processed/add_circumstances/mp_full_data.csv
# - ../../data/4812/processed/add_circumstances/mp_full_data.csv
# - ../../data/2923/processed/add_circumstances/mp_full_data.csv
# - ../../data/8811/processed/add_circumstances/mp_full_data.csv
# - ../../data/2528/processed/add_circumstances/mp_full_data.csv
# - ../../data/453/processed/add_circumstances/mp_full_data.csv
# - ../../data/5993/processed/add_circumstances/mp_full_data.csv
# - ../../data/4622/processed/add_circumstances/mp_full_data.csv
# - ../../data/1961/processed/add_circumstances/mp_full_data.csv
# - ../../data/9906/processed/add_circumstances/mp_full_data.csv
# - ../../data/5531/processed/add_circumstances/mp_full_data.csv
# - ../../data/6529/processed/add_circumstances/mp_full_data.csv
# - ../../data/6971/processed/add_circumstances/mp_full_data.csv
# - ../../data/6985/processed/add_circumstances/mp_full_data.csv
# - ../../data/8675/processed/add_circumstances/mp_full_data.csv
# - ../../data/2454/processed/add_circumstances/mp_full_data.csv
# - ../../data/6000/processed/add_circumstances/mp_full_data.csv
# - ../../data/8700/processed/add_circumstances/mp_full_data.csv
# - ../../data/9873/processed/add_circumstances/mp_full_data.csv
# - ../../data/5676/processed/add_circumstances/mp_full_data.csv
# - ../../data/9274/processed/add_circumstances/mp_full_data.csv
# - ../../data/1019/processed/add_circumstances/mp_full_data.csv
# - ../../data/9610/processed/add_circumstances/mp_full_data.csv
# - ../../data/5812/processed/add_circumstances/mp_full_data.csv
# - ../../data/5223/processed/add_circumstances/mp_full_data.csv
# - ../../data/8990/processed/add_circumstances/mp_full_data.csv
# - ../../data/42/processed/add_circumstances/mp_full_data.csv
# - ../../data/1276/processed/add_circumstances/mp_full_data.csv
# - ../../data/3145/processed/add_circumstances/mp_full_data.csv
# - ../../data/1612/processed/add_circumstances/mp_full_data.csv
# - ../../data/2063/processed/add_circumstances/mp_full_data.csv
# - ../../data/7511/processed/add_circumstances/mp_full_data.csv
# - ../../data/5622/processed/add_circumstances/mp_full_data.csv
# - ../../data/6098/processed/add_circumstances/mp_full_data.csv
# - ../../data/9023/processed/add_circumstances/mp_full_data.csv
# - ../../data/1682/processed/add_circumstances/mp_full_data.csv
# - ../../data/1488/processed/add_circumstances/mp_full_data.csv
# - ../../data/7324/processed/add_circumstances/mp_full_data.csv
# - ../../data/9243/processed/add_circumstances/mp_full_data.csv
# - ../../data/9886/processed/add_circumstances/mp_full_data.csv
# - ../../data/6234/processed/add_circumstances/mp_full_data.csv
# - ../../data/985/processed/add_circumstances/mp_full_data.csv
# - ../../data/7118/processed/add_circumstances/mp_full_data.csv
# - ../../data/4564/processed/add_circumstances/mp_full_data.csv
# - ../../data/2667/processed/add_circumstances/mp_full_data.csv
# - ../../data/5442/processed/add_circumstances/mp_full_data.csv
# - ../../data/6869/processed/add_circumstances/mp_full_data.csv
# - ../../data/4392/processed/add_circumstances/mp_full_data.csv
# - ../../data/3518/processed/add_circumstances/mp_full_data.csv
# - ../../data/783/processed/add_circumstances/mp_full_data.csv
# - ../../data/777/processed/add_circumstances/mp_full_data.csv
# - ../../data/3520/processed/add_circumstances/mp_full_data.csv
# - ../../data/9687/processed/add_circumstances/mp_full_data.csv
# - ../../data/3947/processed/add_circumstances/mp_full_data.csv
# - ../../data/4501/processed/add_circumstances/mp_full_data.csv
# - ../../data/8135/processed/add_circumstances/mp_full_data.csv
# - ../../data/9219/processed/add_circumstances/mp_full_data.csv
# - ../../data/4350/processed/add_circumstances/mp_full_data.csv
# - ../../data/6635/processed/add_circumstances/mp_full_data.csv
# - ../../data/4539/processed/add_circumstances/mp_full_data.csv
# - ../../data/2641/processed/add_circumstances/mp_full_data.csv
# - ../../data/4314/processed/add_circumstances/mp_full_data.csv
# - ../../data/4741/processed/add_circumstances/mp_full_data.csv
# - ../../data/5667/processed/add_circumstances/mp_full_data.csv
# - ../../data/6486/processed/add_circumstances/mp_full_data.csv
# - ../../data/9095/processed/add_circumstances/mp_full_data.csv
# - ../../data/2075/processed/add_circumstances/mp_full_data.csv
# - ../../data/7163/processed/add_circumstances/mp_full_data.csv
# - ../../data/3705/processed/add_circumstances/mp_full_data.csv
# - ../../data/4520/processed/add_circumstances/mp_full_data.csv
# - ../../data/9003/processed/add_circumstances/mp_full_data.csv
# - ../../data/8919/processed/add_circumstances/mp_full_data.csv
# - ../../data/4949/processed/add_circumstances/mp_full_data.csv
# - ../../data/903/processed/add_circumstances/mp_full_data.csv
# - ../../data/8579/processed/add_circumstances/mp_full_data.csv
# - ../../data/2043/processed/add_circumstances/mp_full_data.csv
# - ../../data/190/processed/add_circumstances/mp_full_data.csv
# - ../../data/9863/processed/add_circumstances/mp_full_data.csv
# - ../../data/3795/processed/add_circumstances/mp_full_data.csv
# - ../../data/951/processed/add_circumstances/mp_full_data.csv
# - ../../data/4528/processed/add_circumstances/mp_full_data.csv
# - ../../data/4517/processed/add_circumstances/mp_full_data.csv
# - ../../data/6081/processed/add_circumstances/mp_full_data.csv
# - ../../data/1634/processed/add_circumstances/mp_full_data.csv
# - ../../data/553/processed/add_circumstances/mp_full_data.csv
# - ../../data/3956/processed/add_circumstances/mp_full_data.csv
# - ../../data/4142/processed/add_circumstances/mp_full_data.csv
# - ../../data/5090/processed/add_circumstances/mp_full_data.csv
# - ../../data/3199/processed/add_circumstances/mp_full_data.csv
# - ../../data/3394/processed/add_circumstances/mp_full_data.csv
# - ../../data/2334/processed/add_circumstances/mp_full_data.csv
# - ../../data/6760/processed/add_circumstances/mp_full_data.csv
# - ../../data/270/processed/add_circumstances/mp_full_data.csv
# - ../../data/1314/processed/add_circumstances/mp_full_data.csv
# - ../../data/283/processed/add_circumstances/mp_full_data.csv
# - ../../data/4659/processed/add_circumstances/mp_full_data.csv
# - ../../data/884/processed/add_circumstances/mp_full_data.csv
# - ../../data/9974/processed/add_circumstances/mp_full_data.csv
# - ../../data/8435/processed/add_circumstances/mp_full_data.csv
# - ../../data/3815/processed/add_circumstances/mp_full_data.csv
# - ../../data/1188/processed/add_circumstances/mp_full_data.csv
# - ../../data/212/processed/add_circumstances/mp_full_data.csv
# - ../../data/1940/processed/add_circumstances/mp_full_data.csv
# - ../../data/3419/processed/add_circumstances/mp_full_data.csv
# - ../../data/3614/processed/add_circumstances/mp_full_data.csv
# - ../../data/1143/processed/add_circumstances/mp_full_data.csv
# - ../../data/443/processed/add_circumstances/mp_full_data.csv
# - ../../data/4260/processed/add_circumstances/mp_full_data.csv
# - ../../data/6395/processed/add_circumstances/mp_full_data.csv
# - ../../data/5948/processed/add_circumstances/mp_full_data.csv
# - ../../data/475/processed/add_circumstances/mp_full_data.csv
# - ../../data/1724/processed/add_circumstances/mp_full_data.csv
# - ../../data/1976/processed/add_circumstances/mp_full_data.csv
# - ../../data/5713/processed/add_circumstances/mp_full_data.csv
# - ../../data/4651/processed/add_circumstances/mp_full_data.csv
# - ../../data/416/processed/add_circumstances/mp_full_data.csv
# - ../../data/6792/processed/add_circumstances/mp_full_data.csv
# - ../../data/7016/processed/add_circumstances/mp_full_data.csv
# - ../../data/3213/processed/add_circumstances/mp_full_data.csv
# - ../../data/4009/processed/add_circumstances/mp_full_data.csv
# - ../../data/615/processed/add_circumstances/mp_full_data.csv
# - ../../data/5188/processed/add_circumstances/mp_full_data.csv
# - ../../data/8836/processed/add_circumstances/mp_full_data.csv
# - ../../data/4295/processed/add_circumstances/mp_full_data.csv
# - ../../data/6152/processed/add_circumstances/mp_full_data.csv
# - ../../data/683/processed/add_circumstances/mp_full_data.csv
# - ../../data/9579/processed/add_circumstances/mp_full_data.csv
# - ../../data/1160/processed/add_circumstances/mp_full_data.csv
# - ../../data/4412/processed/add_circumstances/mp_full_data.csv
# - ../../data/9590/processed/add_circumstances/mp_full_data.csv
# - ../../data/3298/processed/add_circumstances/mp_full_data.csv
# - ../../data/5533/processed/add_circumstances/mp_full_data.csv
# - ../../data/2943/processed/add_circumstances/mp_full_data.csv
# - ../../data/3891/processed/add_circumstances/mp_full_data.csv
# - ../../data/4872/processed/add_circumstances/mp_full_data.csv
# - ../../data/5353/processed/add_circumstances/mp_full_data.csv
# - ../../data/7863/processed/add_circumstances/mp_full_data.csv
# - ../../data/3853/processed/add_circumstances/mp_full_data.csv
# - ../../data/6989/processed/add_circumstances/mp_full_data.csv
# - ../../data/8282/processed/add_circumstances/mp_full_data.csv
# - ../../data/8276/processed/add_circumstances/mp_full_data.csv
# - ../../data/253/processed/add_circumstances/mp_full_data.csv
# - ../../data/5338/processed/add_circumstances/mp_full_data.csv
# - ../../data/6927/processed/add_circumstances/mp_full_data.csv
# - ../../data/6918/processed/add_circumstances/mp_full_data.csv
# - ../../data/9950/processed/add_circumstances/mp_full_data.csv
# - ../../data/2910/processed/add_circumstances/mp_full_data.csv
# - ../../data/3809/processed/add_circumstances/mp_full_data.csv
# - ../../data/6729/processed/add_circumstances/mp_full_data.csv
# - ../../data/3051/processed/add_circumstances/mp_full_data.csv
# - ../../data/1953/processed/add_circumstances/mp_full_data.csv
# - ../../data/1195/processed/add_circumstances/mp_full_data.csv
# - ../../data/459/processed/add_circumstances/mp_full_data.csv
# - ../../data/8488/processed/add_circumstances/mp_full_data.csv
# - ../../data/6512/processed/add_circumstances/mp_full_data.csv
# - ../../data/7898/processed/add_circumstances/mp_full_data.csv
# - ../../data/3299/processed/add_circumstances/mp_full_data.csv
# - ../../data/8087/processed/add_circumstances/mp_full_data.csv
# - ../../data/8870/processed/add_circumstances/mp_full_data.csv
# - ../../data/2916/processed/add_circumstances/mp_full_data.csv
# - ../../data/9509/processed/add_circumstances/mp_full_data.csv
# - ../../data/1790/processed/add_circumstances/mp_full_data.csv
# - ../../data/1799/processed/add_circumstances/mp_full_data.csv
# - ../../data/403/processed/add_circumstances/mp_full_data.csv
# - ../../data/7238/processed/add_circumstances/mp_full_data.csv
# - ../../data/6577/processed/add_circumstances/mp_full_data.csv
# - ../../data/7469/processed/add_circumstances/mp_full_data.csv
# - ../../data/9960/processed/add_circumstances/mp_full_data.csv
# - ../../data/4503/processed/add_circumstances/mp_full_data.csv
# - ../../data/7372/processed/add_circumstances/mp_full_data.csv
# - ../../data/1618/processed/add_circumstances/mp_full_data.csv
# - ../../data/4990/processed/add_circumstances/mp_full_data.csv
# - ../../data/8137/processed/add_circumstances/mp_full_data.csv
# - ../../data/3183/processed/add_circumstances/mp_full_data.csv
# - ../../data/3148/processed/add_circumstances/mp_full_data.csv
# - ../../data/3717/processed/add_circumstances/mp_full_data.csv
# - ../../data/5619/processed/add_circumstances/mp_full_data.csv
# - ../../data/9212/processed/add_circumstances/mp_full_data.csv
# - ../../data/781/processed/add_circumstances/mp_full_data.csv
# - ../../data/5413/processed/add_circumstances/mp_full_data.csv
# - ../../data/1210/processed/add_circumstances/mp_full_data.csv
# - ../../data/1274/processed/add_circumstances/mp_full_data.csv
# - ../../data/5049/processed/add_circumstances/mp_full_data.csv
# - ../../data/5071/processed/add_circumstances/mp_full_data.csv
# - ../../data/8597/processed/add_circumstances/mp_full_data.csv
# - ../../data/1077/processed/add_circumstances/mp_full_data.csv
# - ../../data/6636/processed/add_circumstances/mp_full_data.csv
# - ../../data/7146/processed/add_circumstances/mp_full_data.csv
# - ../../data/6609/processed/add_circumstances/mp_full_data.csv
# - ../../data/6299/processed/add_circumstances/mp_full_data.csv
# - ../../data/7179/processed/add_circumstances/mp_full_data.csv
# - ../../data/7717/processed/add_circumstances/mp_full_data.csv
# - ../../data/3171/processed/add_circumstances/mp_full_data.csv
# - ../../data/2854/processed/add_circumstances/mp_full_data.csv
# - ../../data/1289/processed/add_circumstances/mp_full_data.csv
# - ../../data/2458/processed/add_circumstances/mp_full_data.csv
# - ../../data/1216/processed/add_circumstances/mp_full_data.csv
# - ../../data/386/processed/add_circumstances/mp_full_data.csv
# - ../../data/6239/processed/add_circumstances/mp_full_data.csv
# - ../../data/729/processed/add_circumstances/mp_full_data.csv
# - ../../data/3319/processed/add_circumstances/mp_full_data.csv
# - ../../data/7927/processed/add_circumstances/mp_full_data.csv
# - ../../data/8154/processed/add_circumstances/mp_full_data.csv
# - ../../data/8957/processed/add_circumstances/mp_full_data.csv
#
# All matching 'full_data.csv' files have been concatenated into '../../data/full/fake_mp_data_correct.csv'.
# Combined DataFrame shape: (4381, 82)
#
# Column data types:
#   Unnamed: 0: int64
#   reportid: int64
#   misperid: int64
#   initial_risk_level: object
#   current_final_risk_level: object
#   forenames: object
#   surname: object
#   dob: object
#   pob: object
#   age: int64
#   sex: object
#   residence_type: object
#   occdesc: object
#   nominalpersionid: int64
#   missing_since: object
#   date_reported_missing: object
#   day_reported_missing: object
#   length_missing_mins: int64
#   when_traced: object
#   mf_address: object
#   missing_from: object
#   reported_missing_by: object
#   TL_address: object
#   return_method_desc: object
#   circumstances: object
#   entities_landmarks: object
#   entities_addresses: object
#   entities_location_types: object
#   entities_people_names: object
#   entities_people_desc: object
#   entities_people_relat: object
#   entities_pattern_types: object
#   q_1: Int64
#   q_1_explanation: object
#   q_2: Int64
#   q_2_explanation: object
#   q_3: Int64
#   q_3_explanation: object
#   q_4: Int64
#   q_4_explanation: object
#   q_5: Int64
#   q_5_explanation: object
#   q_6: Int64
#   q_6_explanation: object
#   q_7: Int64
#   q_7_explanation: object
#   q_8: Int64
#   q_8_explanation: object
#   q_9: Int64
#   q_9_explanation: object
#   q_10: Int64
#   q_10_explanation: object
#   q_11: Int64
#   q_11_explanation: object
#   q_12: Int64
#   q_12_explanation: object
#   q_13: Int64
#   q_13_explanation: object
#   q_14: Int64
#   q_14_explanation: object
#   q_15: Int64
#   q_15_explanation: object
#   q_16: Int64
#   q_16_explanation: object
#   q_17: Int64
#   q_17_explanation: object
#   q_18: Int64
#   q_18_explanation: object
#   q_19: Int64
#   q_19_explanation: object
#   q_20: Int64
#   q_20_explanation: object
#   q_21: Int64
#   q_21_explanation: object
#   q_22: Int64
#   q_22_explanation: object
#   q_23: Int64
#   q_23_explanation: object
#   q_24: Int64
#   q_24_explanation: object
#   q_25: Int64
#   q_25_explanation: object
# {'1019',
#  '1077',
#  '1143',
#  '1160',
#  '1188',
#  '1195',
#  '1210',
#  '1216',
#  '1274',
#  '1276',
#  '1289',
#  '1314',
#  '1375',
#  '1381',
#  '1466',
#  '1488',
#  '157',
#  '1612',
#  '1618',
#  '1634',
#  '1682',
#  '1724',
#  '1727',
#  '1790',
#  '1799',
#  '1839',
#  '1864',
#  '190',
#  '1940',
#  '1953',
#  '1961',
#  '1976',
#  '1989',
#  '2043',
#  '2063',
#  '2075',
#  '212',
#  '2280',
#  '2324',
#  '2334',
#  '2338',
#  '2454',
#  '2458',
#  '2470',
#  '2516',
#  '2528',
#  '253',
#  '2641',
#  '266',
#  '2667',
#  '2674',
#  '2681',
#  '2686',
#  '270',
#  '2738',
#  '281',
#  '2817',
#  '283',
#  '2854',
#  '2910',
#  '2915',
#  '2916',
#  '2923',
#  '2937',
#  '2943',
#  '2971',
#  '3051',
#  '3145',
#  '3148',
#  '3171',
#  '3183',
#  '3199',
#  '3213',
#  '3298',
#  '3299',
#  '3319',
#  '3394',
#  '3419',
#  '3465',
#  '3518',
#  '3520',
#  '3602',
#  '3614',
#  '3633',
#  '3651',
#  '3705',
#  '3717',
#  '3795',
#  '3809',
#  '3811',
#  '3815',
#  '3827',
#  '3853',
#  '386',
#  '3891',
#  '3938',
#  '3947',
#  '3956',
#  '4009',
#  '403',
#  '4115',
#  '4142',
#  '416',
#  '4182',
#  '42',
#  '422',
#  '4260',
#  '4295',
#  '4314',
#  '4350',
#  '4386',
#  '4392',
#  '4412',
#  '443',
#  '4474',
#  '4501',
#  '4503',
#  '4512',
#  '4517',
#  '4520',
#  '4528',
#  '453',
#  '4539',
#  '4564',
#  '459',
#  '4622',
#  '4649',
#  '4651',
#  '4659',
#  '4741',
#  '475',
#  '4812',
#  '4872',
#  '490',
#  '4949',
#  '4990',
#  '5049',
#  '5051',
#  '5071',
#  '5090',
#  '51',
#  '5179',
#  '5188',
#  '5223',
#  '5264',
#  '5338',
#  '5353',
#  '5413',
#  '5433',
#  '5442',
#  '5508',
#  '5523',
#  '553',
#  '5531',
#  '5533',
#  '5564',
#  '5619',
#  '5622',
#  '5631',
#  '5667',
#  '5676',
#  '5713',
#  '5772',
#  '5806',
#  '5812',
#  '5902',
#  '5904',
#  '5942',
#  '5948',
#  '5993',
#  '6000',
#  '6081',
#  '6082',
#  '6098',
#  '6116',
#  '615',
#  '6152',
#  '6234',
#  '6239',
#  '6299',
#  '6383',
#  '6395',
#  '6486',
#  '6512',
#  '6529',
#  '6542',
#  '656',
#  '6575',
#  '6577',
#  '6609',
#  '6635',
#  '6636',
#  '6681',
#  '6722',
#  '6729',
#  '6760',
#  '6792',
#  '6827',
#  '683',
#  '6869',
#  '6875',
#  '6918',
#  '6927',
#  '6971',
#  '6985',
#  '6989',
#  '7016',
#  '7118',
#  '7132',
#  '7146',
#  '7163',
#  '7179',
#  '7238',
#  '7288',
#  '729',
#  '7324',
#  '7372',
#  '7469',
#  '7479',
#  '7511',
#  '7594',
#  '7668',
#  '7686',
#  '7717',
#  '777',
#  '781',
#  '783',
#  '7851',
#  '7863',
#  '7898',
#  '7927',
#  '8087',
#  '8096',
#  '8111',
#  '8135',
#  '8137',
#  '8154',
#  '8256',
#  '8276',
#  '8282',
#  '8431',
#  '8435',
#  '8455',
#  '8479',
#  '8488',
#  '851',
#  '8526',
#  '8542',
#  '857',
#  '8575',
#  '8579',
#  '8597',
#  '8675',
#  '8700',
#  '8713',
#  '8723',
#  '8811',
#  '8836',
#  '884',
#  '8870',
#  '8919',
#  '8940',
#  '8957',
#  '8990',
#  '9003',
#  '9023',
#  '903',
#  '9039',
#  '9062',
#  '908',
#  '9095',
#  '9126',
#  '9156',
#  '9212',
#  '9219',
#  '9243',
#  '9274',
#  '9315',
#  '9354',
#  '9505',
#  '9509',
#  '951',
#  '9516',
#  '9545',
#  '9579',
#  '9590',
#  '9610',
#  '962',
#  '9635',
#  '9650',
#  '9687',
#  '9737',
#  '985',
#  '9863',
#  '9873',
#  '9886',
#  '9906',
#  '9950',
#  '9960',
#  '9974'}

# %%
import glob
import pandas as pd
import os

def concatenate_full_data_csvs(output_filename='../../data/full/fake_vp_data_correct.csv'):
    file_paths = glob.glob('../../data/**/processed/vpd/vpd_full_data.csv', recursive=True)
    print(file_paths)
    if not file_paths:
        print("No 'full_data.csv' files found in any subdirectories.")
        return

    filtered_file_paths = [
        f for f in file_paths
        if 'vpd' in os.path.normpath(f).replace(os.sep, '/')
    ]

    if not filtered_file_paths:
        print("No 'full_data.csv' files matching the 'add_cir' pattern were found.")
        print("Ensure your directory structure is like 'your_id-add_cir/full_data.csv'.")
        return

    print(f"Found {len(filtered_file_paths)} matching files:")
    for f in filtered_file_paths:
        print(f"- {f}")

    all_dataframes = []
    # Read each filtered CSV file into a pandas DataFrame
    for file_path in filtered_file_paths:
        try:
            df = pd.read_csv(file_path)
            all_dataframes.append(df)
        except Exception as e:
            print(f"Error reading {file_path}: {e}. Skipping this file.")

    if not all_dataframes:
        print("No DataFrames were successfully read to concatenate.")
        return

    # Concatenate all DataFrames into a single DataFrame
    combined_df = pd.concat(all_dataframes, ignore_index=True)
    for col in combined_df.columns:
        if combined_df[col].dtype == 'float64':
            # Check if all non-null values are whole numbers
            non_null_values = combined_df[col].dropna()
            if len(non_null_values) > 0 and all(non_null_values == non_null_values.astype(int)):
                # Convert to nullable integer type to handle potential NaN values
                combined_df[col] = combined_df[col].astype('Int64')
    # Save the combined DataFrame to a new CSV file
    try:
        start_number = 100001

        # Fix for the incident ids
        new_id_sequence = np.arange(start_number, start_number + len(combined_df))
        combined_df['VPD_NOMINALINCIDENTID_PK'] = new_id_sequence
        combined_df
        combined_df.to_csv(output_filename, index=False)
        print(f"\nAll matching 'full_data.csv' files have been concatenated into '{output_filename}'.")
        print(f"Combined DataFrame shape: {combined_df.shape}")
    except Exception as e:
        print(f"Error saving the combined CSV to '{output_filename}': {e}")
    
    ids = set()
    for f in filtered_file_paths:
        ids.add(f.split('/')[3])
    return ids
ids_vp = concatenate_full_data_csvs()
# Out:
# ['../../data/4386/processed/vpd/vpd_full_data.csv', '../../data/1864/processed/vpd/vpd_full_data.csv', '../../data/5433/processed/vpd/vpd_full_data.csv', '../../data/8542/processed/vpd/vpd_full_data.csv', '../../data/4512/processed/vpd/vpd_full_data.csv', '../../data/4182/processed/vpd/vpd_full_data.csv', '../../data/6681/processed/vpd/vpd_full_data.csv', '../../data/157/processed/vpd/vpd_full_data.csv', '../../data/2470/processed/vpd/vpd_full_data.csv', '../../data/2817/processed/vpd/vpd_full_data.csv', '../../data/8723/processed/vpd/vpd_full_data.csv', '../../data/6827/processed/vpd/vpd_full_data.csv', '../../data/8940/processed/vpd/vpd_full_data.csv', '../../data/2674/processed/vpd/vpd_full_data.csv', '../../data/1839/processed/vpd/vpd_full_data.csv', '../../data/3938/processed/vpd/vpd_full_data.csv', '../../data/1466/processed/vpd/vpd_full_data.csv', '../../data/962/processed/vpd/vpd_full_data.csv', '../../data/9062/processed/vpd/vpd_full_data.csv', '../../data/6875/processed/vpd/vpd_full_data.csv', '../../data/5051/processed/vpd/vpd_full_data.csv', '../../data/6082/processed/vpd/vpd_full_data.csv', '../../data/2280/processed/vpd/vpd_full_data.csv', '../../data/9650/processed/vpd/vpd_full_data.csv', '../../data/51/processed/vpd/vpd_full_data.csv', '../../data/9039/processed/vpd/vpd_full_data.csv', '../../data/5264/processed/vpd/vpd_full_data.csv', '../../data/8575/processed/vpd/vpd_full_data.csv', '../../data/908/processed/vpd/vpd_full_data.csv', '../../data/8111/processed/vpd/vpd_full_data.csv', '../../data/5631/processed/vpd/vpd_full_data.csv', '../../data/7132/processed/vpd/vpd_full_data.csv', '../../data/4115/processed/vpd/vpd_full_data.csv', '../../data/2686/processed/vpd/vpd_full_data.csv', '../../data/8713/processed/vpd/vpd_full_data.csv', '../../data/9635/processed/vpd/vpd_full_data.csv', '../../data/2681/processed/vpd/vpd_full_data.csv', '../../data/8526/processed/vpd/vpd_full_data.csv', '../../data/7594/processed/vpd/vpd_full_data.csv', '../../data/5806/processed/vpd/vpd_full_data.csv', '../../data/9315/processed/vpd/vpd_full_data.csv', '../../data/1375/processed/vpd/vpd_full_data.csv', '../../data/1381/processed/vpd/vpd_full_data.csv', '../../data/7288/processed/vpd/vpd_full_data.csv', '../../data/5179/processed/vpd/vpd_full_data.csv', '../../data/2738/processed/vpd/vpd_full_data.csv', '../../data/5942/processed/vpd/vpd_full_data.csv', '../../data/1727/processed/vpd/vpd_full_data.csv', '../../data/3827/processed/vpd/vpd_full_data.csv', '../../data/422/processed/vpd/vpd_full_data.csv', '../../data/8256/processed/vpd/vpd_full_data.csv', '../../data/5772/processed/vpd/vpd_full_data.csv', '../../data/3811/processed/vpd/vpd_full_data.csv', '../../data/2937/processed/vpd/vpd_full_data.csv', '../../data/7479/processed/vpd/vpd_full_data.csv', '../../data/8431/processed/vpd/vpd_full_data.csv', '../../data/8455/processed/vpd/vpd_full_data.csv', '../../data/5523/processed/vpd/vpd_full_data.csv', '../../data/9545/processed/vpd/vpd_full_data.csv', '../../data/1989/processed/vpd/vpd_full_data.csv', '../../data/9126/processed/vpd/vpd_full_data.csv', '../../data/2338/processed/vpd/vpd_full_data.csv', '../../data/9516/processed/vpd/vpd_full_data.csv', '../../data/7686/processed/vpd/vpd_full_data.csv', '../../data/281/processed/vpd/vpd_full_data.csv', '../../data/8096/processed/vpd/vpd_full_data.csv', '../../data/9354/processed/vpd/vpd_full_data.csv', '../../data/6575/processed/vpd/vpd_full_data.csv', '../../data/3651/processed/vpd/vpd_full_data.csv', '../../data/4474/processed/vpd/vpd_full_data.csv', '../../data/9505/processed/vpd/vpd_full_data.csv', '../../data/9737/processed/vpd/vpd_full_data.csv', '../../data/6116/processed/vpd/vpd_full_data.csv', '../../data/266/processed/vpd/vpd_full_data.csv', '../../data/5904/processed/vpd/vpd_full_data.csv', '../../data/857/processed/vpd/vpd_full_data.csv', '../../data/7668/processed/vpd/vpd_full_data.csv', '../../data/5564/processed/vpd/vpd_full_data.csv', '../../data/8479/processed/vpd ...
# Found 300 matching files:
# - ../../data/4386/processed/vpd/vpd_full_data.csv
# - ../../data/1864/processed/vpd/vpd_full_data.csv
# - ../../data/5433/processed/vpd/vpd_full_data.csv
# - ../../data/8542/processed/vpd/vpd_full_data.csv
# - ../../data/4512/processed/vpd/vpd_full_data.csv
# - ../../data/4182/processed/vpd/vpd_full_data.csv
# - ../../data/6681/processed/vpd/vpd_full_data.csv
# - ../../data/157/processed/vpd/vpd_full_data.csv
# - ../../data/2470/processed/vpd/vpd_full_data.csv
# - ../../data/2817/processed/vpd/vpd_full_data.csv
# - ../../data/8723/processed/vpd/vpd_full_data.csv
# - ../../data/6827/processed/vpd/vpd_full_data.csv
# - ../../data/8940/processed/vpd/vpd_full_data.csv
# - ../../data/2674/processed/vpd/vpd_full_data.csv
# - ../../data/1839/processed/vpd/vpd_full_data.csv
# - ../../data/3938/processed/vpd/vpd_full_data.csv
# - ../../data/1466/processed/vpd/vpd_full_data.csv
# - ../../data/962/processed/vpd/vpd_full_data.csv
# - ../../data/9062/processed/vpd/vpd_full_data.csv
# - ../../data/6875/processed/vpd/vpd_full_data.csv
# - ../../data/5051/processed/vpd/vpd_full_data.csv
# - ../../data/6082/processed/vpd/vpd_full_data.csv
# - ../../data/2280/processed/vpd/vpd_full_data.csv
# - ../../data/9650/processed/vpd/vpd_full_data.csv
# - ../../data/51/processed/vpd/vpd_full_data.csv
# - ../../data/9039/processed/vpd/vpd_full_data.csv
# - ../../data/5264/processed/vpd/vpd_full_data.csv
# - ../../data/8575/processed/vpd/vpd_full_data.csv
# - ../../data/908/processed/vpd/vpd_full_data.csv
# - ../../data/8111/processed/vpd/vpd_full_data.csv
# - ../../data/5631/processed/vpd/vpd_full_data.csv
# - ../../data/7132/processed/vpd/vpd_full_data.csv
# - ../../data/4115/processed/vpd/vpd_full_data.csv
# - ../../data/2686/processed/vpd/vpd_full_data.csv
# - ../../data/8713/processed/vpd/vpd_full_data.csv
# - ../../data/9635/processed/vpd/vpd_full_data.csv
# - ../../data/2681/processed/vpd/vpd_full_data.csv
# - ../../data/8526/processed/vpd/vpd_full_data.csv
# - ../../data/7594/processed/vpd/vpd_full_data.csv
# - ../../data/5806/processed/vpd/vpd_full_data.csv
# - ../../data/9315/processed/vpd/vpd_full_data.csv
# - ../../data/1375/processed/vpd/vpd_full_data.csv
# - ../../data/1381/processed/vpd/vpd_full_data.csv
# - ../../data/7288/processed/vpd/vpd_full_data.csv
# - ../../data/5179/processed/vpd/vpd_full_data.csv
# - ../../data/2738/processed/vpd/vpd_full_data.csv
# - ../../data/5942/processed/vpd/vpd_full_data.csv
# - ../../data/1727/processed/vpd/vpd_full_data.csv
# - ../../data/3827/processed/vpd/vpd_full_data.csv
# - ../../data/422/processed/vpd/vpd_full_data.csv
# - ../../data/8256/processed/vpd/vpd_full_data.csv
# - ../../data/5772/processed/vpd/vpd_full_data.csv
# - ../../data/3811/processed/vpd/vpd_full_data.csv
# - ../../data/2937/processed/vpd/vpd_full_data.csv
# - ../../data/7479/processed/vpd/vpd_full_data.csv
# - ../../data/8431/processed/vpd/vpd_full_data.csv
# - ../../data/8455/processed/vpd/vpd_full_data.csv
# - ../../data/5523/processed/vpd/vpd_full_data.csv
# - ../../data/9545/processed/vpd/vpd_full_data.csv
# - ../../data/1989/processed/vpd/vpd_full_data.csv
# - ../../data/9126/processed/vpd/vpd_full_data.csv
# - ../../data/2338/processed/vpd/vpd_full_data.csv
# - ../../data/9516/processed/vpd/vpd_full_data.csv
# - ../../data/7686/processed/vpd/vpd_full_data.csv
# - ../../data/281/processed/vpd/vpd_full_data.csv
# - ../../data/8096/processed/vpd/vpd_full_data.csv
# - ../../data/9354/processed/vpd/vpd_full_data.csv
# - ../../data/6575/processed/vpd/vpd_full_data.csv
# - ../../data/3651/processed/vpd/vpd_full_data.csv
# - ../../data/4474/processed/vpd/vpd_full_data.csv
# - ../../data/9505/processed/vpd/vpd_full_data.csv
# - ../../data/9737/processed/vpd/vpd_full_data.csv
# - ../../data/6116/processed/vpd/vpd_full_data.csv
# - ../../data/266/processed/vpd/vpd_full_data.csv
# - ../../data/5904/processed/vpd/vpd_full_data.csv
# - ../../data/857/processed/vpd/vpd_full_data.csv
# - ../../data/7668/processed/vpd/vpd_full_data.csv
# - ../../data/5564/processed/vpd/vpd_full_data.csv
# - ../../data/8479/processed/vpd/vpd_full_data.csv
# - ../../data/3633/processed/vpd/vpd_full_data.csv
# - ../../data/6722/processed/vpd/vpd_full_data.csv
# - ../../data/490/processed/vpd/vpd_full_data.csv
# - ../../data/7851/processed/vpd/vpd_full_data.csv
# - ../../data/5508/processed/vpd/vpd_full_data.csv
# - ../../data/656/processed/vpd/vpd_full_data.csv
# - ../../data/3602/processed/vpd/vpd_full_data.csv
# - ../../data/2516/processed/vpd/vpd_full_data.csv
# - ../../data/2971/processed/vpd/vpd_full_data.csv
# - ../../data/6383/processed/vpd/vpd_full_data.csv
# - ../../data/2915/processed/vpd/vpd_full_data.csv
# - ../../data/5902/processed/vpd/vpd_full_data.csv
# - ../../data/6542/processed/vpd/vpd_full_data.csv
# - ../../data/2324/processed/vpd/vpd_full_data.csv
# - ../../data/851/processed/vpd/vpd_full_data.csv
# - ../../data/4649/processed/vpd/vpd_full_data.csv
# - ../../data/9156/processed/vpd/vpd_full_data.csv
# - ../../data/3465/processed/vpd/vpd_full_data.csv
# - ../../data/4812/processed/vpd/vpd_full_data.csv
# - ../../data/2923/processed/vpd/vpd_full_data.csv
# - ../../data/8811/processed/vpd/vpd_full_data.csv
# - ../../data/2528/processed/vpd/vpd_full_data.csv
# - ../../data/453/processed/vpd/vpd_full_data.csv
# - ../../data/5993/processed/vpd/vpd_full_data.csv
# - ../../data/4622/processed/vpd/vpd_full_data.csv
# - ../../data/1961/processed/vpd/vpd_full_data.csv
# - ../../data/9906/processed/vpd/vpd_full_data.csv
# - ../../data/5531/processed/vpd/vpd_full_data.csv
# - ../../data/6529/processed/vpd/vpd_full_data.csv
# - ../../data/6971/processed/vpd/vpd_full_data.csv
# - ../../data/6985/processed/vpd/vpd_full_data.csv
# - ../../data/8675/processed/vpd/vpd_full_data.csv
# - ../../data/2454/processed/vpd/vpd_full_data.csv
# - ../../data/6000/processed/vpd/vpd_full_data.csv
# - ../../data/8700/processed/vpd/vpd_full_data.csv
# - ../../data/9873/processed/vpd/vpd_full_data.csv
# - ../../data/5676/processed/vpd/vpd_full_data.csv
# - ../../data/9274/processed/vpd/vpd_full_data.csv
# - ../../data/1019/processed/vpd/vpd_full_data.csv
# - ../../data/9610/processed/vpd/vpd_full_data.csv
# - ../../data/5812/processed/vpd/vpd_full_data.csv
# - ../../data/5223/processed/vpd/vpd_full_data.csv
# - ../../data/8990/processed/vpd/vpd_full_data.csv
# - ../../data/42/processed/vpd/vpd_full_data.csv
# - ../../data/1276/processed/vpd/vpd_full_data.csv
# - ../../data/3145/processed/vpd/vpd_full_data.csv
# - ../../data/1612/processed/vpd/vpd_full_data.csv
# - ../../data/2063/processed/vpd/vpd_full_data.csv
# - ../../data/7511/processed/vpd/vpd_full_data.csv
# - ../../data/5622/processed/vpd/vpd_full_data.csv
# - ../../data/6098/processed/vpd/vpd_full_data.csv
# - ../../data/9023/processed/vpd/vpd_full_data.csv
# - ../../data/1682/processed/vpd/vpd_full_data.csv
# - ../../data/1488/processed/vpd/vpd_full_data.csv
# - ../../data/7324/processed/vpd/vpd_full_data.csv
# - ../../data/9243/processed/vpd/vpd_full_data.csv
# - ../../data/9886/processed/vpd/vpd_full_data.csv
# - ../../data/6234/processed/vpd/vpd_full_data.csv
# - ../../data/985/processed/vpd/vpd_full_data.csv
# - ../../data/7118/processed/vpd/vpd_full_data.csv
# - ../../data/4564/processed/vpd/vpd_full_data.csv
# - ../../data/2667/processed/vpd/vpd_full_data.csv
# - ../../data/5442/processed/vpd/vpd_full_data.csv
# - ../../data/6869/processed/vpd/vpd_full_data.csv
# - ../../data/4392/processed/vpd/vpd_full_data.csv
# - ../../data/3518/processed/vpd/vpd_full_data.csv
# - ../../data/783/processed/vpd/vpd_full_data.csv
# - ../../data/777/processed/vpd/vpd_full_data.csv
# - ../../data/3520/processed/vpd/vpd_full_data.csv
# - ../../data/9687/processed/vpd/vpd_full_data.csv
# - ../../data/3947/processed/vpd/vpd_full_data.csv
# - ../../data/4501/processed/vpd/vpd_full_data.csv
# - ../../data/8135/processed/vpd/vpd_full_data.csv
# - ../../data/9219/processed/vpd/vpd_full_data.csv
# - ../../data/4350/processed/vpd/vpd_full_data.csv
# - ../../data/6635/processed/vpd/vpd_full_data.csv
# - ../../data/4539/processed/vpd/vpd_full_data.csv
# - ../../data/2641/processed/vpd/vpd_full_data.csv
# - ../../data/4314/processed/vpd/vpd_full_data.csv
# - ../../data/4741/processed/vpd/vpd_full_data.csv
# - ../../data/5667/processed/vpd/vpd_full_data.csv
# - ../../data/6486/processed/vpd/vpd_full_data.csv
# - ../../data/9095/processed/vpd/vpd_full_data.csv
# - ../../data/2075/processed/vpd/vpd_full_data.csv
# - ../../data/7163/processed/vpd/vpd_full_data.csv
# - ../../data/3705/processed/vpd/vpd_full_data.csv
# - ../../data/4520/processed/vpd/vpd_full_data.csv
# - ../../data/9003/processed/vpd/vpd_full_data.csv
# - ../../data/8919/processed/vpd/vpd_full_data.csv
# - ../../data/4949/processed/vpd/vpd_full_data.csv
# - ../../data/903/processed/vpd/vpd_full_data.csv
# - ../../data/8579/processed/vpd/vpd_full_data.csv
# - ../../data/2043/processed/vpd/vpd_full_data.csv
# - ../../data/190/processed/vpd/vpd_full_data.csv
# - ../../data/9863/processed/vpd/vpd_full_data.csv
# - ../../data/3795/processed/vpd/vpd_full_data.csv
# - ../../data/951/processed/vpd/vpd_full_data.csv
# - ../../data/4528/processed/vpd/vpd_full_data.csv
# - ../../data/4517/processed/vpd/vpd_full_data.csv
# - ../../data/6081/processed/vpd/vpd_full_data.csv
# - ../../data/1634/processed/vpd/vpd_full_data.csv
# - ../../data/553/processed/vpd/vpd_full_data.csv
# - ../../data/3956/processed/vpd/vpd_full_data.csv
# - ../../data/4142/processed/vpd/vpd_full_data.csv
# - ../../data/5090/processed/vpd/vpd_full_data.csv
# - ../../data/3199/processed/vpd/vpd_full_data.csv
# - ../../data/3394/processed/vpd/vpd_full_data.csv
# - ../../data/2334/processed/vpd/vpd_full_data.csv
# - ../../data/6760/processed/vpd/vpd_full_data.csv
# - ../../data/270/processed/vpd/vpd_full_data.csv
# - ../../data/1314/processed/vpd/vpd_full_data.csv
# - ../../data/283/processed/vpd/vpd_full_data.csv
# - ../../data/4659/processed/vpd/vpd_full_data.csv
# - ../../data/884/processed/vpd/vpd_full_data.csv
# - ../../data/9974/processed/vpd/vpd_full_data.csv
# - ../../data/8435/processed/vpd/vpd_full_data.csv
# - ../../data/3815/processed/vpd/vpd_full_data.csv
# - ../../data/1188/processed/vpd/vpd_full_data.csv
# - ../../data/212/processed/vpd/vpd_full_data.csv
# - ../../data/1940/processed/vpd/vpd_full_data.csv
# - ../../data/3419/processed/vpd/vpd_full_data.csv
# - ../../data/3614/processed/vpd/vpd_full_data.csv
# - ../../data/1143/processed/vpd/vpd_full_data.csv
# - ../../data/443/processed/vpd/vpd_full_data.csv
# - ../../data/4260/processed/vpd/vpd_full_data.csv
# - ../../data/6395/processed/vpd/vpd_full_data.csv
# - ../../data/5948/processed/vpd/vpd_full_data.csv
# - ../../data/475/processed/vpd/vpd_full_data.csv
# - ../../data/1724/processed/vpd/vpd_full_data.csv
# - ../../data/1976/processed/vpd/vpd_full_data.csv
# - ../../data/5713/processed/vpd/vpd_full_data.csv
# - ../../data/4651/processed/vpd/vpd_full_data.csv
# - ../../data/416/processed/vpd/vpd_full_data.csv
# - ../../data/6792/processed/vpd/vpd_full_data.csv
# - ../../data/7016/processed/vpd/vpd_full_data.csv
# - ../../data/3213/processed/vpd/vpd_full_data.csv
# - ../../data/4009/processed/vpd/vpd_full_data.csv
# - ../../data/615/processed/vpd/vpd_full_data.csv
# - ../../data/5188/processed/vpd/vpd_full_data.csv
# - ../../data/8836/processed/vpd/vpd_full_data.csv
# - ../../data/4295/processed/vpd/vpd_full_data.csv
# - ../../data/6152/processed/vpd/vpd_full_data.csv
# - ../../data/683/processed/vpd/vpd_full_data.csv
# - ../../data/9579/processed/vpd/vpd_full_data.csv
# - ../../data/1160/processed/vpd/vpd_full_data.csv
# - ../../data/4412/processed/vpd/vpd_full_data.csv
# - ../../data/9590/processed/vpd/vpd_full_data.csv
# - ../../data/3298/processed/vpd/vpd_full_data.csv
# - ../../data/5533/processed/vpd/vpd_full_data.csv
# - ../../data/2943/processed/vpd/vpd_full_data.csv
# - ../../data/3891/processed/vpd/vpd_full_data.csv
# - ../../data/4872/processed/vpd/vpd_full_data.csv
# - ../../data/5353/processed/vpd/vpd_full_data.csv
# - ../../data/7863/processed/vpd/vpd_full_data.csv
# - ../../data/3853/processed/vpd/vpd_full_data.csv
# - ../../data/6989/processed/vpd/vpd_full_data.csv
# - ../../data/8282/processed/vpd/vpd_full_data.csv
# - ../../data/8276/processed/vpd/vpd_full_data.csv
# - ../../data/253/processed/vpd/vpd_full_data.csv
# - ../../data/5338/processed/vpd/vpd_full_data.csv
# - ../../data/6927/processed/vpd/vpd_full_data.csv
# - ../../data/6918/processed/vpd/vpd_full_data.csv
# - ../../data/9950/processed/vpd/vpd_full_data.csv
# - ../../data/2910/processed/vpd/vpd_full_data.csv
# - ../../data/3809/processed/vpd/vpd_full_data.csv
# - ../../data/6729/processed/vpd/vpd_full_data.csv
# - ../../data/3051/processed/vpd/vpd_full_data.csv
# - ../../data/1953/processed/vpd/vpd_full_data.csv
# - ../../data/1195/processed/vpd/vpd_full_data.csv
# - ../../data/459/processed/vpd/vpd_full_data.csv
# - ../../data/8488/processed/vpd/vpd_full_data.csv
# - ../../data/6512/processed/vpd/vpd_full_data.csv
# - ../../data/7898/processed/vpd/vpd_full_data.csv
# - ../../data/3299/processed/vpd/vpd_full_data.csv
# - ../../data/8087/processed/vpd/vpd_full_data.csv
# - ../../data/8870/processed/vpd/vpd_full_data.csv
# - ../../data/2916/processed/vpd/vpd_full_data.csv
# - ../../data/9509/processed/vpd/vpd_full_data.csv
# - ../../data/1790/processed/vpd/vpd_full_data.csv
# - ../../data/1799/processed/vpd/vpd_full_data.csv
# - ../../data/403/processed/vpd/vpd_full_data.csv
# - ../../data/7238/processed/vpd/vpd_full_data.csv
# - ../../data/6577/processed/vpd/vpd_full_data.csv
# - ../../data/7469/processed/vpd/vpd_full_data.csv
# - ../../data/9960/processed/vpd/vpd_full_data.csv
# - ../../data/4503/processed/vpd/vpd_full_data.csv
# - ../../data/7372/processed/vpd/vpd_full_data.csv
# - ../../data/1618/processed/vpd/vpd_full_data.csv
# - ../../data/4990/processed/vpd/vpd_full_data.csv
# - ../../data/8137/processed/vpd/vpd_full_data.csv
# - ../../data/3183/processed/vpd/vpd_full_data.csv
# - ../../data/3148/processed/vpd/vpd_full_data.csv
# - ../../data/3717/processed/vpd/vpd_full_data.csv
# - ../../data/5619/processed/vpd/vpd_full_data.csv
# - ../../data/9212/processed/vpd/vpd_full_data.csv
# - ../../data/781/processed/vpd/vpd_full_data.csv
# - ../../data/5413/processed/vpd/vpd_full_data.csv
# - ../../data/1210/processed/vpd/vpd_full_data.csv
# - ../../data/1274/processed/vpd/vpd_full_data.csv
# - ../../data/5049/processed/vpd/vpd_full_data.csv
# - ../../data/5071/processed/vpd/vpd_full_data.csv
# - ../../data/8597/processed/vpd/vpd_full_data.csv
# - ../../data/1077/processed/vpd/vpd_full_data.csv
# - ../../data/6636/processed/vpd/vpd_full_data.csv
# - ../../data/7146/processed/vpd/vpd_full_data.csv
# - ../../data/6609/processed/vpd/vpd_full_data.csv
# - ../../data/6299/processed/vpd/vpd_full_data.csv
# - ../../data/7179/processed/vpd/vpd_full_data.csv
# - ../../data/7717/processed/vpd/vpd_full_data.csv
# - ../../data/3171/processed/vpd/vpd_full_data.csv
# - ../../data/2854/processed/vpd/vpd_full_data.csv
# - ../../data/1289/processed/vpd/vpd_full_data.csv
# - ../../data/2458/processed/vpd/vpd_full_data.csv
# - ../../data/1216/processed/vpd/vpd_full_data.csv
# - ../../data/386/processed/vpd/vpd_full_data.csv
# - ../../data/6239/processed/vpd/vpd_full_data.csv
# - ../../data/729/processed/vpd/vpd_full_data.csv
# - ../../data/3319/processed/vpd/vpd_full_data.csv
# - ../../data/7927/processed/vpd/vpd_full_data.csv
# - ../../data/8154/processed/vpd/vpd_full_data.csv
# - ../../data/8957/processed/vpd/vpd_full_data.csv
#
# All matching 'full_data.csv' files have been concatenated into '../../data/full/fake_vp_data_correct.csv'.
# Combined DataFrame shape: (2574, 84)

# %%
# sanity check to see if generated for all
list(id_mp-ids_vp)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # sanity check to see if generated for all
# ----> 2 list(id_mp-ids_vp)
#
# NameError: name 'id_mp' is not defined
